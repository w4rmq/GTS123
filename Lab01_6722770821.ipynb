# %%
#Question 1

print("1 2 3 4 5 6 7 8 9")
print("2               8")
print("3               7")
print("4               6")
print("5 6 7 8 9 8 7 6 5")
print("6")
print("7")
print("8")
print("9")
# Out:
# 1 2 3 4 5 6 7 8 9
# 2               8
# 3               7
# 4               6
# 5 6 7 8 9 8 7 6 5
# 6
# 7
# 8
# 9

# %%
#Question 2

print('''XX X X X X X X X XX
XX O X O X O X O XX
XX X O X O X O X XX
XX O X O X O X O XX
XX X X X X X X X XX''')
# Out:
# XX X X X X X X X XX
# XX O X O X O X O XX
# XX X O X O X O X XX
# XX O X O X O X O XX
# XX X X X X X X X XX

# %%
#Question 3

print('''1
2 3
4 5 6
6 7 9 10''')
# Out:
# 1
# 2 3
# 4 5 6
# 6 7 9 10

# %%
#Question 4

print('''**********
*********
********
*******
******
*****
****
***
**
*''')
# Out:
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
#Question 5

print('''h
he
hel
hell
hello
hello w
hello wo
hello wor
hello worl
hello world''')
# Out:
# h
# he
# hel
# hell
# hello
# hello w
# hello wo
# hello wor
# hello worl
# hello world

# %%
#Question 6

print(''' ____   __   __   ____
/ ___) (  ) (  ) (_  _)
\___ \  )(   )(    )(
(____/ (__) (__)  (__)''')
# Out:
#  ____   __   __   ____
# / ___) (  ) (  ) (_  _)
# \___ \  )(   )(    )(
# (____/ (__) (__)  (__)

# %%
#Question 7

print('''     /\\
    /**\\
   /****\\
  /******\\
 /********\\
/**********\\
------------''')
# Out:
#      /\
#     /**\
#    /****\
#   /******\
#  /********\
# /**********\
# ------------

# %%
#Question 8

print('''Group Number: 1
------------------------
1: 6722770821 Mr.Saphon Choochuay
2: 6722770839 Mr.Panukorn Waiyavat
3: 6722770847 Mr.Ananit Thaveesapmanee
4: 6722771597 Mr.Rachpoll Sabkaew
5: 6722771639 Mr.Thanakit Kongthawin
6: 6722772058 Ms.Chayanit Promkutkao
7: 6722772157 Ms.Supitcha Avasatdaporn
8: 6722772199 Ms.Nicharee Teeratrakul
9: 6722772298 Mr.Phakhin Kitsomboonchai
10: 6722772306 Ms.Nuntakarn Khanunthong''')
# Out:
# Group Number: 1
# ------------------------
# 1: 6722770821 Mr.Saphon Choochuay
# 2: 6722770839 Mr.Panukorn Waiyavat
# 3: 6722770847 Mr.Ananit Thaveesapmanee
# 4: 6722771597 Mr.Rachpoll Sabkaew
# 5: 6722771639 Mr.Thanakit Kongthawin
# 6: 6722772058 Ms.Chayanit Promkutkao
# 7: 6722772157 Ms.Supitcha Avasatdaporn
# 8: 6722772199 Ms.Nicharee Teeratrakul
# 9: 6722772298 Mr.Phakhin Kitsomboonchai
# 10: 6722772306 Ms.Nuntakarn Khanunthong

# %%
#Question 9

print('''(\ /)
(. .)
O(")(")''')
# Out:
# (\ /)
# (. .)
# O(")(")

# %%
#Question 10

print('''Name: Saphon Choochuay
Birthday: 13/01/2005
Email: 6722770821@g.siit.tu.ac.th
Major: GE''')
# Out:
# Name: Saphon Choochuay
# Birthday: 13/01/2005
# Email: 6722770821@g.siit.tu.ac.th
# Major: GE
